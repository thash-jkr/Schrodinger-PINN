# %% [markdown]
# ## Initial condition - Ground state
# - In the last [notebook](./1_2022shah.ipynb), the initial condition we used was a superposition of ground and first excited state
# - For this model, we use ground state alone to see if the PINN was able to predict this problem properly as well
# - Everything else remain the same apart from the initial condition
# - I will highlight the major changes in this notebook when compared to the previous one

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
hbar = 1
m = 1
omega = 1

x_min = -np.pi
x_max = np.pi
t_min = 0
t_max = 2 * np.pi

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using MPS backend for Apple GPU acceleration!")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using cuda")
else:
    device = torch.device("cpu")
    print("Using CPU instead.")
# Out:
# Using cuda

# %%
class PINN(nn.Module):
	def __init__(self, layers):
		super(PINN, self).__init__()
		self.hidden_layers = nn.ModuleList()
		for units in layers[1:-1]:
			self.hidden_layers.append(nn.Linear(in_features=layers[0], out_features=units))
			layers[0] = units

		self.output_layer = nn.Linear(layers[-2], layers[-1])

	def forward(self, inputs):
		x, t = inputs
		X = torch.stack((x, t), dim=1)

		for layer in self.hidden_layers:
			X = layer(X)
			X = torch.tanh(X)

		output = self.output_layer(X)
		psi_real = output[:, 0]
		psi_img = output[:, 1]

		return psi_real, psi_img

# %%
layers = [2, 512, 512, 512, 512, 512, 512, 2]

# %%
n_collocation = 3140
n_initial = 314
n_boundary = 200

# %%
def generator():
	x_collocation = np.random.uniform(x_min, x_max, n_collocation)
	t_collocation = np.random.uniform(t_min, t_max, n_collocation)

	x_initial = np.random.uniform(x_min, x_max, n_initial)
	t_initial = np.full(n_initial, t_min)

	x_boundary = np.concatenate([np.full(n_boundary // 2, x_min), np.full(n_boundary // 2, x_max)])
	t_boundary = np.random.uniform(t_min, t_max, n_boundary)

	x_collocation_torch = torch.from_numpy(x_collocation).float().to(device)
	t_collocation_torch = torch.from_numpy(t_collocation).float().to(device)

	x_initial_torch  = torch.from_numpy(x_initial).float().to(device)
	t_initial_torch  = torch.from_numpy(t_initial).float().to(device)

	x_boundary_torch = torch.from_numpy(x_boundary).float().to(device)
	t_boundary_torch = torch.from_numpy(t_boundary).float().to(device)

	return x_collocation_torch, t_collocation_torch, x_initial_torch, t_initial_torch, x_boundary_torch, t_boundary_torch

# %%
model = PINN(layers)
model.to(device)
# Out:
# PINN(
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=2, out_features=512, bias=True)
#     (1-5): 5 x Linear(in_features=512, out_features=512, bias=True)
#   )
#   (output_layer): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
optimizer = torch.optim.Adam(
  model.parameters(),
  lr=0.001,
  betas=(0.09, 0.999)
)

a0 = 0.001
decay_rate = 0.9
steps = 2000

def exp_decay(step):
  return decay_rate ** (step / steps)

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=exp_decay)

# %% [markdown]
# #### Here, for the initial condition loss, I will only be using ground state alone instead of the superposition of ground and first excited state

# %%
def loss_function(x_collocation_torch, t_collocation_torch, x_initial_torch, t_initial_torch, x_boundary_torch, t_boundary_torch):
	#pde loss
	x_collocation_torch = x_collocation_torch.clone().requires_grad_(True)
	t_collocation_torch = t_collocation_torch.clone().requires_grad_(True)

	u, v = model((x_collocation_torch, t_collocation_torch))

	du_dt = torch.autograd.grad(u, t_collocation_torch, grad_outputs=torch.ones_like(u), create_graph=True)[0]
	du_dx = torch.autograd.grad(u, x_collocation_torch, grad_outputs=torch.ones_like(u), create_graph=True)[0]
	d2u_dx2 = torch.autograd.grad(du_dx, x_collocation_torch, grad_outputs=torch.ones_like(du_dx), create_graph=True)[0]

	dv_dt = torch.autograd.grad(v, t_collocation_torch, grad_outputs=torch.ones_like(v), create_graph=True)[0]
	dv_dx = torch.autograd.grad(v, x_collocation_torch, grad_outputs=torch.ones_like(v), create_graph=True)[0]
	d2v_dx2 = torch.autograd.grad(dv_dx, x_collocation_torch, grad_outputs=torch.ones_like(dv_dx), create_graph=True)[0]

	real = -dv_dt + 0.5 * d2u_dx2 - 0.5 * (x_collocation_torch ** 2) * u
	img = du_dt + 0.5 * d2v_dx2 - 0.5 * (x_collocation_torch ** 2) * v

	physics_loss = torch.mean(real ** 2 + img ** 2)




	#initial condition loss
	u_i, v_i = model((x_initial_torch, t_initial_torch))

	psi_0 = ((1 / np.pi) ** 0.25) * torch.exp(-0.5 * (x_initial_torch ** 2))
	psi_1 = psi_0 * np.sqrt(2) * x_initial_torch
	psi_initial_actual = psi_0

	initial_condition_loss = torch.mean((u_i - psi_initial_actual) ** 2) + torch.mean((v_i - 0) ** 2)




	#boundary condition loss
	u_b, v_b = model((x_boundary_torch, t_boundary_torch))
	boundary_condition_loss = torch.mean(u_b ** 2) + torch.mean(v_b ** 2)

	return physics_loss, initial_condition_loss, boundary_condition_loss

# %%
epochs = 150000
history = []

for epoch in range(1, epochs+1):
  optimizer.zero_grad()

  physics_loss, initial_condition_loss, boundary_condition_loss = loss_function(*generator())
  total_loss = 10 * physics_loss + initial_condition_loss + boundary_condition_loss

  total_loss.backward()
  optimizer.step()
  scheduler.step()

  history.append({"total_loss": total_loss.item() ,"physics_loss": physics_loss.item(), "initial_condition_loss": initial_condition_loss.item(), "boundary_condition_loss": boundary_condition_loss.item()})

  if epoch % 1500 == 0:
    print(f"Epoch {epoch}/{epochs}")
    print(f"Total loss: {total_loss.item():.4e}")
    print(f"Physics loss: {physics_loss.item():.4e}")
    print(f"Initial condition loss: {initial_condition_loss.item():.4e}")
    print(f"Boundary condition loss: {boundary_condition_loss.item():.4e}")
    print("-" * 50)
# Out:
# Epoch 1500/150000
# Total loss: 6.7861e-02
# Physics loss: 5.4559e-03
# Initial condition loss: 1.2649e-02
# Boundary condition loss: 6.5273e-04
# --------------------------------------------------
# Epoch 3000/150000
# Total loss: 1.5107e+01
# Physics loss: 1.4412e+00
# Initial condition loss: 5.1887e-01
# Boundary condition loss: 1.7572e-01
# --------------------------------------------------
# Epoch 4500/150000
# Total loss: 6.5595e+00
# Physics loss: 5.9948e-01
# Initial condition loss: 4.3338e-01
# Boundary condition loss: 1.3137e-01
# --------------------------------------------------
# Epoch 6000/150000
# Total loss: 3.7579e+00
# Physics loss: 3.3697e-01
# Initial condition loss: 3.4644e-01
# Boundary condition loss: 4.1773e-02
# --------------------------------------------------
# Epoch 7500/150000
# Total loss: 1.0614e+00
# Physics loss: 7.8450e-02
# Initial condition loss: 2.5768e-01
# Boundary condition loss: 1.9264e-02
# --------------------------------------------------
# Boundary condition loss: 1.4457e-04
# --------------------------------------------------
# Epoch 60000/150000
# Total loss: 6.0423e-03
# Physics loss: 5.5627e-04
# Initial condition loss: 2.5666e-04
# Boundary condition loss: 2.2293e-04
# --------------------------------------------------
# Epoch 61500/150000
# Total loss: 4.6425e-03
# Physics loss: 4.4071e-04
# Initial condition loss: 1.8767e-04
# Boundary condition loss: 4.7760e-05
# --------------------------------------------------
# Epoch 63000/150000
# Total loss: 9.1832e-03
# Physics loss: 8.8737e-04
# Initial condition loss: 1.4734e-04
# Boundary condition loss: 1.6217e-04
# --------------------------------------------------
# Epoch 64500/150000
# Total loss: 1.3847e-03
# Physics loss: 1.3255e-04
# Initial condition loss: 2.0216e-05
# Boundary condition loss: 3.9024e-05
# --------------------------------------------------
# Epoch 66000/150000
# Total loss: 4.6421e-04
# Physics loss: 4.3343e-05
# Initial condition loss: 3.5133e-06
# Boundary condition loss: 2.7260e-05
# --------------------------------------------------
# Epoch 67500/150000
# Total loss: 3.9085e-03
# Physics loss: 3.7941e-04
# Initial condition loss: 7.9234e-05
# Boundary condition loss: 3.5166e-05
# --------------------------------------------------
# Epoch 69000/150000
# Total loss: 3.0635e-03
# Physics loss: 2.9727e-04
# Initial condition loss: 5.4803e-05
# Boundary condition loss: 3.5949e-05
# --------------------------------------------------
# Epoch 70500/150000
# Total loss: 3.9631e-03
# Physics loss: 3.6887e-04
# Initial condition loss: 1.2434e-04
# Boundary condition loss: 1.5007e-04
# --------------------------------------------------
# Epoch 72000/150000
# Total loss: 3.1903e-03
# Physics loss: 2.9638e-04
# Initial condition loss: 9.7683e-05
# Boundary condition loss: 1.2885e-04
# --------------------------------------------------
# Epoch 73500/150000
# Total loss: 9.0248e-04
# Physics loss: 8.6311e-05
# Initial condition loss: 2.1803e-05
# Boundary condition loss: 1.7571e-05
# --------------------------------------------------
# Epoch 75000/150000
# Total loss: 4.8369e-04
# Physics loss: 4.3975e-05
# Initial condition loss: 1.5016e-05
# Boundary condition loss: 2.8927e-05
# --------------------------------------------------
# Epoch 76500/150000
# Total loss: 8.0281e-04
# Physics loss: 7.2916e-05
# Initial condition loss: 2.7976e-05
# Boundary condition loss: 4.5675e-05
# --------------------------------------------------
# Epoch 78000/150000
# Total loss: 1.4500e-03
# Physics loss: 1.3467e-04
# Initial condition loss: 3.6576e-05
# Boundary condition loss: 6.6673e-05
# --------------------------------------------------
# Epoch 79500/150000
# Total loss: 1.0842e-03
# Physics loss: 1.0415e-04
# Initial condition loss: 2.3428e-05
# Boundary condition loss: 1.9266e-05
# --------------------------------------------------
# Epoch 81000/150000
# Total loss: 8.4413e-04
# Physics loss: 8.0516e-05
# Initial condition loss: 2.1188e-05
# Boundary condition loss: 1.7779e-05
# --------------------------------------------------
# Epoch 82500/150000
# Total loss: 1.0366e-03
# Physics loss: 9.8643e-05
# Initial condition loss: 3.1402e-05
# Boundary condition loss: 1.8784e-05
# --------------------------------------------------
# Epoch 84000/150000
# Total loss: 1.4974e-03
# Physics loss: 1.3984e-04
# Initial condition loss: 3.2063e-05
# Boundary condition loss: 6.6870e-05
# --------------------------------------------------
# Epoch 85500/150000
# Total loss: 1.1153e-03
# Physics loss: 1.0675e-04
# Initial condition loss: 2.5177e-05
# Boundary condition loss: 2.2617e-05
# --------------------------------------------------
# Epoch 87000/150000
# Total loss: 6.2890e-04
# Physics loss: 5.9319e-05
# Initial condition loss: 1.8448e-05
# Boundary condition loss: 1.7256e-05
# --------------------------------------------------
# Epoch 88500/150000
# Total loss: 1.0723e-03
# Physics loss: 9.9817e-05
# Initial condition loss: 2.8939e-05
# Boundary condition loss: 4.5193e-05
# --------------------------------------------------
# Epoch 90000/150000
# Total loss: 1.1564e-04
# Physics loss: 9.0853e-06
# Initial condition loss: 2.4766e-06
# Boundary condition loss: 2.2309e-05
# --------------------------------------------------
# Epoch 91500/150000
# Total loss: 1.2163e-04
# Physics loss: 1.0196e-05
# Initial condition loss: 1.8697e-06
# Boundary condition loss: 1.7797e-05
# --------------------------------------------------
# Epoch 93000/150000
# Total loss: 7.5566e-05
# Physics loss: 5.9559e-06
# Initial condition loss: 1.8503e-06
# Boundary condition loss: 1.4157e-05
# --------------------------------------------------
# Epoch 94500/150000
# Total loss: 6.4443e-04
# Physics loss: 6.0976e-05
# Initial condition loss: 1.4034e-05
# Boundary condition loss: 2.0642e-05
# --------------------------------------------------
# Epoch 96000/150000
# Total loss: 8.7667e-05
# Physics loss: 7.2031e-06
# Initial condition loss: 2.4253e-06
# Boundary condition loss: 1.3210e-05
# --------------------------------------------------
# Epoch 97500/150000
# Total loss: 2.4581e-04
# Physics loss: 2.1812e-05
# Initial condition loss: 5.1549e-06
# Boundary condition loss: 2.2536e-05
# --------------------------------------------------
# Epoch 99000/150000
# Total loss: 4.8412e-05
# Physics loss: 3.1966e-06
# Initial condition loss: 9.3857e-07
# Boundary condition loss: 1.5507e-05
# --------------------------------------------------
# Epoch 100500/150000
# Total loss: 2.6883e-05
# Physics loss: 1.3502e-06
# Initial condition loss: 6.3251e-07
# Boundary condition loss: 1.2748e-05
# --------------------------------------------------
# Epoch 102000/150000
# Total loss: 1.0406e-04
# Physics loss: 8.7091e-06
# Initial condition loss: 1.6976e-06
# Boundary condition loss: 1.5276e-05
# --------------------------------------------------
# Epoch 103500/150000
# Total loss: 4.4980e-04
# Physics loss: 4.2598e-05
# Initial condition loss: 9.9803e-06
# Boundary condition loss: 1.3845e-05
# --------------------------------------------------
# Epoch 105000/150000
# Total loss: 5.4606e-05
# Physics loss: 4.2405e-06
# Initial condition loss: 1.3277e-06
# Boundary condition loss: 1.0874e-05
# --------------------------------------------------
# Epoch 106500/150000
# Total loss: 4.4000e-05
# Physics loss: 3.0043e-06
# Initial condition loss: 6.0417e-07
# Boundary condition loss: 1.3353e-05
# --------------------------------------------------
# Epoch 108000/150000
# Total loss: 2.1530e-04
# Physics loss: 1.9253e-05
# Initial condition loss: 5.5206e-06
# Boundary condition loss: 1.7248e-05
# --------------------------------------------------
# Epoch 109500/150000
# Total loss: 1.0494e-04
# Total loss: 1.8201e-05
# Physics loss: 1.0646e-06
# Initial condition loss: 4.0229e-07
# Boundary condition loss: 7.1534e-06
# --------------------------------------------------
# Epoch 136500/150000
# Total loss: 1.7959e-05
# Physics loss: 8.9380e-07
# Initial condition loss: 2.9428e-07
# Boundary condition loss: 8.7271e-06
# --------------------------------------------------
# Epoch 138000/150000
# Total loss: 1.4343e-05
# Physics loss: 6.4370e-07
# Initial condition loss: 3.0890e-07
# Boundary condition loss: 7.5968e-06
# --------------------------------------------------
# Epoch 139500/150000
# Total loss: 1.4678e-05
# Physics loss: 6.5154e-07
# Initial condition loss: 2.5797e-07
# Boundary condition loss: 7.9049e-06
# --------------------------------------------------
# Epoch 141000/150000
# Total loss: 1.4934e-05
# Physics loss: 6.8447e-07
# Initial condition loss: 2.7884e-07
# Boundary condition loss: 7.8108e-06
# --------------------------------------------------
# Epoch 142500/150000
# Total loss: 1.6536e-05
# Physics loss: 7.8988e-07
# Initial condition loss: 2.5454e-07
# Boundary condition loss: 8.3826e-06
# --------------------------------------------------
# Epoch 144000/150000
# Total loss: 1.2978e-05
# Physics loss: 5.5995e-07
# Initial condition loss: 2.2616e-07
# Boundary condition loss: 7.1524e-06
# --------------------------------------------------
# Epoch 145500/150000
# Total loss: 1.3528e-05
# Physics loss: 5.9695e-07
# Initial condition loss: 3.2796e-07
# Boundary condition loss: 7.2307e-06
# --------------------------------------------------
# Epoch 147000/150000
# Total loss: 1.7723e-05
# Physics loss: 8.9085e-07
# Initial condition loss: 2.4270e-07
# Boundary condition loss: 8.5715e-06
# --------------------------------------------------
# Epoch 148500/150000
# Total loss: 1.2854e-05
# Physics loss: 5.4419e-07
# Initial condition loss: 2.3603e-07
# Boundary condition loss: 7.1761e-06
# --------------------------------------------------
# Epoch 150000/150000
# Total loss: 1.2572e-05
# Physics loss: 5.3493e-07
# Initial condition loss: 2.3184e-07
# Boundary condition loss: 6.9907e-06
# --------------------------------------------------

# %%
total_loss_history = [record['total_loss'] for record in history]
physics_loss_history = [record['physics_loss'] for record in history]
initial_condition_loss_history = [record['initial_condition_loss'] for record in history]
boundary_condition_loss_history = [record['boundary_condition_loss'] for record in history]

epochs_range = range(1, epochs + 1)

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 10))

# Total Loss
axs[0, 0].plot(epochs_range, total_loss_history, color='blue')
axs[0, 0].set_title('Total Loss')
axs[0, 0].set_xlabel('Epochs')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].grid(True)
axs[0, 0].set_yscale("log")

# Physics Loss
axs[0, 1].plot(epochs_range, physics_loss_history, color='orange')
axs[0, 1].set_title('Physics Loss')
axs[0, 1].set_xlabel('Epochs')
axs[0, 1].set_ylabel('Loss')
axs[0, 1].grid(True)
axs[0, 1].set_yscale("log")

# Initial Condition Loss
axs[1, 0].plot(epochs_range, initial_condition_loss_history, color='green')
axs[1, 0].set_title('Initial Condition Loss')
axs[1, 0].set_xlabel('Epochs')
axs[1, 0].set_ylabel('Loss')
axs[1, 0].grid(True)
axs[1, 0].set_yscale("log")

# Boundary Condition Loss
axs[1, 1].plot(epochs_range, boundary_condition_loss_history, color='red')
axs[1, 1].set_title('Boundary Condition Loss')
axs[1, 1].set_xlabel('Epochs')
axs[1, 1].set_ylabel('Loss')
axs[1, 1].grid(True)
axs[1, 1].set_yscale("log")

plt.tight_layout()
plt.show()

# %%
Nx = 628
Nt = 628

x_values = np.linspace(x_min, x_max, Nx)
t_values = np.linspace(t_min, t_max, Nt)

# %% [markdown]
# #### This will be the analytical solution of the problem when initial condition is the ground state

# %%
def analytical(x, t):
    A = ((1 / np.pi) ** 0.25) * np.exp(-(x ** 2) / 2)
    B = np.exp(-1j * 0.5 * t)
    return A * B

# %%
psi_real_analytical = np.zeros((Nx, Nt), dtype=np.float64)
psi_img_analytical = np.zeros((Nx, Nt), dtype=np.float64)

for i, x in enumerate(x_values):
    for j, t in enumerate(t_values):
        psi_x_t = analytical(x, t)

        psi_real_analytical[i, j] = np.real(psi_x_t)
        psi_img_analytical[i, j] = np.imag(psi_x_t)

# %%
plt.figure(figsize=(8, 6))
psi_sq_analytical = psi_real_analytical ** 2 + psi_img_analytical ** 2

plt.pcolormesh(x_values, t_values, psi_sq_analytical.transpose(), shading="auto")
plt.colorbar(label='|psi(x,t)|^2')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Analytical |psi|^2')
plt.show()

# %%
x_values_torch = torch.from_numpy(x_values).float().to(device)
t_values_torch = torch.from_numpy(t_values).float().to(device)

x_grid, t_grid = torch.meshgrid(x_values_torch, t_values_torch, indexing="ij")

x_flat = torch.reshape(x_grid, [-1])
t_flat = torch.reshape(t_grid, [-1])

psi_real_pinn, psi_img_pinn = model((x_flat, t_flat))

psi_real_pinn = torch.reshape(psi_real_pinn, (Nx, Nt))
psi_img_pinn = torch.reshape(psi_img_pinn, (Nx, Nt))

psi_real_pinn = psi_real_pinn.detach().cpu().numpy()
psi_img_pinn = psi_img_pinn.detach().cpu().numpy()

# %%
plt.figure(figsize=(8, 6))
psi_sq = psi_real_pinn ** 2 + psi_img_pinn ** 2

plt.pcolormesh(x_values, t_values, psi_sq.transpose(), shading="auto")
plt.colorbar(label='|psi(x,t)|^2')
plt.xlabel('x')
plt.ylabel('t')
plt.title('PINN |psi|^2')
plt.show()

# %%
plt.figure(figsize=(8, 6))
psi_sq_diff = np.abs(psi_sq - psi_sq_analytical)

plt.pcolormesh(x_values, t_values, psi_sq_diff.transpose(), shading="auto")
plt.colorbar(label='|psi(x,t)|^2')
plt.xlabel('x')
plt.ylabel('t')
plt.title('PINN |psi|^2')
plt.show()

# %%
psi_analytical_mag = psi_real_analytical ** 2 + psi_img_analytical ** 2
psi_pinn_mag = psi_real_pinn ** 2 + psi_img_pinn ** 2

mse = (np.square(psi_analytical_mag - psi_pinn_mag)).mean()

print(f"Mean Squared Error: {mse:.3e}")
# Out:
# Mean Squared Error: 2.729e-07

# %%
from scipy.integrate import simpson

norms = []

for i in range(628):
	psi_sq = psi_real_pinn[:, i] ** 2 + psi_img_pinn[:, i] ** 2
	normalization = simpson(psi_sq, x=x_values)
	norms.append(normalization)

plt.figure(figsize=(8,5))
plt.plot(t_values, norms, '-', label='Normalization')
plt.axhline(1.0, color='red', linestyle='--', label='Expected = 1')
plt.xlabel('Time (ps)')
plt.ylabel('Normalization')
plt.title('Wavefunction Normalization Over Time')
plt.legend()
plt.grid(True)
plt.show()
