# %% [markdown]
# ## Baseline Model
# - We once again trained a model to solve the Schrodinger equation for an electron trapped in a 1-D harmonic potential
# - Similiar to the system in [this notebook](./2_2022shah_ground.ipynb), but this time, we use meV, ps and nm units instead of atomic units
# - Since the system changes in terms of x and t domain, this model require some changes to the model architecture compared to our previous models

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy.constants import pi, speed_of_light, elementary_charge, electron_mass, hbar

# Change of units
me_SI = electron_mass           # Electron mass in kg
hbar_SI = hbar                  # Reduced Planck constant in J·s
e_SI = elementary_charge        # Elementary charge in C
c_SI = speed_of_light           # Speed of light in m/s
h_SI = hbar_SI * 2 * pi         # Planck constant in J·s

meV = e_SI * 1e-3               # 1 meV in Joules
nm = 1e-9                       # 1 nm in meters
ps = 1e-12                      # 1 ps in seconds

c = c_SI * ps / nm              # Speed of light in nm/ps (~299792.458 nm/ps)
e = 1e3                         # 1 eV = 1e3 meV
hbar_meV_ps = hbar_SI / (meV * ps)   # hbar in meV·ps
h_bar_meV_ps = hbar_meV_ps           # Alias
me = me_SI * c_SI**2 / meV / c**2    # Electron mass in meV·ps²/nm²

# %%
hbar = hbar_meV_ps
m = me

omega = 1 / hbar

x_min = -30 # nm
x_max = 30 # nm
t_min = 0 # ps
t_max = 20 # ps

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using MPS backend for Apple GPU acceleration!")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using cuda")
else:
    device = torch.device("cpu")
    print("Using CPU instead.")
# Out:
# Using cuda

# %%
class PINN(nn.Module):
	def __init__(self, layers):
		super(PINN, self).__init__()
		self.hidden_layers = nn.ModuleList()
		for units in layers[1:-1]:
			self.hidden_layers.append(nn.Linear(in_features=layers[0], out_features=units))
			layers[0] = units

		self.output_layer = nn.Linear(layers[-2], layers[-1])

	def forward(self, inputs):
		x, t = inputs
		X = torch.stack((x, t), dim=1)

		for layer in self.hidden_layers:
			X = layer(X)
			X = torch.tanh(X)

		output = self.output_layer(X)
		psi_real = output[:, 0]
		psi_img = output[:, 1]

		return psi_real, psi_img

# %%
layers = [2, 512, 512, 512, 512, 512, 512, 2]

# %%
n_collocation = 3000
n_initial = 400
n_boundary = 200

# %%
def generator():
	x_collocation = np.random.uniform(x_min, x_max, n_collocation)
	t_collocation = np.random.uniform(t_min, t_max, n_collocation)

	x_initial = np.random.uniform(x_min, x_max, n_initial)
	t_initial = np.full(n_initial, t_min)

	x_boundary = np.concatenate([np.full(n_boundary // 2, x_min), np.full(n_boundary // 2, x_max)])
	t_boundary = np.random.uniform(t_min, t_max, n_boundary)

	x_collocation_torch = torch.from_numpy(x_collocation).float().to(device)
	t_collocation_torch = torch.from_numpy(t_collocation).float().to(device)

	x_initial_torch  = torch.from_numpy(x_initial).float().to(device)
	t_initial_torch  = torch.from_numpy(t_initial).float().to(device)

	x_boundary_torch = torch.from_numpy(x_boundary).float().to(device)
	t_boundary_torch = torch.from_numpy(t_boundary).float().to(device)

	return x_collocation_torch, t_collocation_torch, x_initial_torch, t_initial_torch, x_boundary_torch, t_boundary_torch

# %%
model = PINN(layers)
model.to(device)
# Out:
# PINN(
#   (hidden_layers): ModuleList(
#     (0): Linear(in_features=2, out_features=512, bias=True)
#     (1-5): 5 x Linear(in_features=512, out_features=512, bias=True)
#   )
#   (output_layer): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# #### One change we made to the model architecture are with the beta1 and beta2 of the Adam optimizer

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001,
    betas=(0.9, 0.9)
)

decay_rate = 0.9
steps = 2000

def exp_decay(step):
    return decay_rate ** (step / steps)

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=exp_decay)

# %%
def loss_function(x_collocation_torch, t_collocation_torch, x_initial_torch, t_initial_torch, x_boundary_torch, t_boundary_torch):
    # pde loss
    x_collocation_torch = x_collocation_torch.clone().requires_grad_(True)
    t_collocation_torch = t_collocation_torch.clone().requires_grad_(True)

    u, v = model((x_collocation_torch, t_collocation_torch))

    du_dt = torch.autograd.grad(u, t_collocation_torch, grad_outputs=torch.ones_like(u), create_graph=True)[0]
    du_dx = torch.autograd.grad(u, x_collocation_torch, grad_outputs=torch.ones_like(u), create_graph=True)[0]
    d2u_dx2 = torch.autograd.grad(du_dx, x_collocation_torch, grad_outputs=torch.ones_like(du_dx), create_graph=True)[0]

    dv_dt = torch.autograd.grad(v, t_collocation_torch, grad_outputs=torch.ones_like(v), create_graph=True)[0]
    dv_dx = torch.autograd.grad(v, x_collocation_torch, grad_outputs=torch.ones_like(v), create_graph=True)[0]
    d2v_dx2 = torch.autograd.grad(dv_dx, x_collocation_torch, grad_outputs=torch.ones_like(dv_dx), create_graph=True)[0]

    real = -hbar * dv_dt + ((hbar ** 2) / (2 * m)) * d2u_dx2 - 0.5 * m * (omega ** 2) * (x_collocation_torch ** 2) * u
    img = hbar * du_dt + ((hbar ** 2) / (2 * m)) * d2v_dx2 - 0.5 * m * (omega ** 2) * (x_collocation_torch ** 2) * v

    physics_loss = torch.mean(real ** 2 + img ** 2)



    
    #initial condition loss
    u_i, v_i = model((x_initial_torch, t_initial_torch))
    psi_initial_actual = (((m * omega) / (np.pi * hbar)) ** 0.25) * torch.exp(((-m * omega) / (2 * hbar)) * (x_initial_torch ** 2))
    initial_condition_loss = torch.mean((u_i - psi_initial_actual) ** 2) + torch.mean((v_i - 0) ** 2)



    
    #boundary condition loss
    u_b, v_b = model((x_boundary_torch, t_boundary_torch))
    boundary_condition_loss = torch.mean(u_b ** 2) + torch.mean(v_b ** 2)

    return physics_loss, initial_condition_loss, boundary_condition_loss

# %%
epochs = 150000
history = []

for epoch in range(1, epochs+1):
  optimizer.zero_grad()

  physics_loss, initial_condition_loss, boundary_condition_loss = loss_function(*generator())
  total_loss = 10 * physics_loss + initial_condition_loss + boundary_condition_loss

  total_loss.backward()
  optimizer.step()
  scheduler.step()

  history.append({"total_loss": total_loss.item() ,"physics_loss": physics_loss.item(), "initial_condition_loss": initial_condition_loss.item(), "boundary_condition_loss": boundary_condition_loss.item()})

  if epoch % 1500 == 0:
    print(f"Epoch {epoch}/{epochs}")
    print(f"Total loss: {total_loss.item():.4e}")
    print(f"Physics loss: {physics_loss.item():.4e}")
    print(f"Initial condition loss: {initial_condition_loss.item():.4e}")
    print(f"Boundary condition loss: {boundary_condition_loss.item():.4e}")
    print("-" * 50)
# Out:
# Epoch 1500/150000
# Total loss: 1.9013e-03
# Physics loss: 1.5354e-04
# Initial condition loss: 3.5749e-04
# Boundary condition loss: 8.4768e-06
# --------------------------------------------------
# Epoch 3000/150000
# Total loss: 5.4505e-04
# Physics loss: 5.1291e-05
# Initial condition loss: 3.1416e-05
# Boundary condition loss: 7.2141e-07
# --------------------------------------------------
# Epoch 4500/150000
# Total loss: 3.8151e-04
# Physics loss: 3.5439e-05
# Initial condition loss: 2.6737e-05
# Boundary condition loss: 3.8733e-07
# --------------------------------------------------
# Epoch 6000/150000
# Total loss: 3.6330e-04
# Physics loss: 3.5819e-05
# Initial condition loss: 4.9186e-06
# Boundary condition loss: 1.9164e-07
# --------------------------------------------------
# Epoch 7500/150000
# Total loss: 2.5250e-04
# Physics loss: 2.4986e-05
# Initial condition loss: 2.3764e-06
# Boundary condition loss: 2.6125e-07
# --------------------------------------------------
# Epoch 9000/150000
# Total loss: 2.0189e-04
# Physics loss: 1.9958e-05
# Initial condition loss: 1.7883e-06
# Boundary condition loss: 5.2666e-07
# --------------------------------------------------
# Epoch 10500/150000
# Total loss: 1.3240e-04
# Physics loss: 1.3077e-05
# Initial condition loss: 1.3015e-06
# Boundary condition loss: 3.2666e-07
# --------------------------------------------------
# Epoch 12000/150000
# Total loss: 1.0131e-04
# Physics loss: 9.9760e-06
# Initial condition loss: 1.1776e-06
# Boundary condition loss: 3.7187e-07
# --------------------------------------------------
# Epoch 13500/150000
# Total loss: 6.5796e-05
# Physics loss: 6.3881e-06
# Initial condition loss: 1.6343e-06
# Boundary condition loss: 2.8027e-07
# --------------------------------------------------
# Epoch 15000/150000
# Total loss: 7.7378e-05
# Physics loss: 7.1351e-06
# Initial condition loss: 5.6161e-06
# Boundary condition loss: 4.1062e-07
# --------------------------------------------------
# Epoch 16500/150000
# Total loss: 8.5972e-05
# Physics loss: 8.2520e-06
# Initial condition loss: 3.1419e-06
# Boundary condition loss: 3.1047e-07
# --------------------------------------------------
# Epoch 18000/150000
# Total loss: 4.6350e-05
# Physics loss: 4.4950e-06
# Initial condition loss: 1.0989e-06
# Boundary condition loss: 3.0149e-07
# --------------------------------------------------
# Epoch 19500/150000
# Total loss: 4.9858e-05
# Physics loss: 4.8592e-06
# Initial condition loss: 8.7825e-07
# Boundary condition loss: 3.8843e-07
# --------------------------------------------------
# Epoch 21000/150000
# Total loss: 3.0901e-05
# Physics loss: 3.0360e-06
# Initial condition loss: 2.4547e-07
# Boundary condition loss: 2.9569e-07
# --------------------------------------------------
# Epoch 22500/150000
# Total loss: 2.1712e-05
# Physics loss: 2.1160e-06
# Initial condition loss: 1.7902e-07
# Boundary condition loss: 3.7279e-07
# --------------------------------------------------
# Epoch 24000/150000
# Total loss: 4.9029e-05
# Physics loss: 4.8080e-06
# Initial condition loss: 6.6245e-07
# Boundary condition loss: 2.8571e-07
# --------------------------------------------------
# Epoch 25500/150000
# Total loss: 1.9123e-05
# Physics loss: 1.7854e-06
# Initial condition loss: 9.8288e-07
# Boundary condition loss: 2.8630e-07
# --------------------------------------------------
# Epoch 27000/150000
# Total loss: 3.2100e-05
# Physics loss: 3.1480e-06
# Initial condition loss: 2.6307e-07
# Boundary condition loss: 3.5712e-07
# --------------------------------------------------
# Epoch 28500/150000
# Total loss: 1.1938e-05
# Physics loss: 1.1634e-06
# Initial condition loss: 6.2492e-08
# Boundary condition loss: 2.4192e-07
# --------------------------------------------------
# Epoch 30000/150000
# Total loss: 1.0934e-05
# Physics loss: 1.0034e-06
# Initial condition loss: 6.9331e-07
# Boundary condition loss: 2.0733e-07
# --------------------------------------------------
# Epoch 31500/150000
# Total loss: 6.1164e-06
# Physics loss: 5.8590e-07
# Initial condition loss: 5.5214e-08
# Boundary condition loss: 2.0214e-07
# --------------------------------------------------
# Epoch 33000/150000
# Total loss: 8.0189e-06
# Physics loss: 7.7414e-07
# Initial condition loss: 6.8868e-08
# Boundary condition loss: 2.0866e-07
# --------------------------------------------------
# Epoch 34500/150000
# Total loss: 7.9521e-06
# Physics loss: 7.6600e-07
# Initial condition loss: 9.2407e-08
# Boundary condition loss: 1.9963e-07
# --------------------------------------------------
# Epoch 36000/150000
# Total loss: 7.7850e-06
# Physics loss: 7.3586e-07
# Initial condition loss: 2.3416e-07
# Boundary condition loss: 1.9224e-07
# --------------------------------------------------
# Epoch 37500/150000
# Total loss: 4.7495e-06
# Physics loss: 4.4772e-07
# Initial condition loss: 9.4509e-08
# Boundary condition loss: 1.7780e-07
# --------------------------------------------------
# Epoch 39000/150000
# Total loss: 4.2281e-06
# Physics loss: 3.9950e-07
# Initial condition loss: 5.4419e-08
# Boundary condition loss: 1.7870e-07
# --------------------------------------------------
# Epoch 40500/150000
# Total loss: 3.9386e-06
# Physics loss: 3.6479e-07
# Initial condition loss: 1.0326e-07
# Boundary condition loss: 1.8742e-07
# --------------------------------------------------
# Epoch 42000/150000
# Total loss: 3.8948e-06
# Physics loss: 3.6432e-07
# Initial condition loss: 1.1735e-07
# Boundary condition loss: 1.3427e-07
# --------------------------------------------------
# Epoch 43500/150000
# Total loss: 2.9284e-06
# Physics loss: 2.7719e-07
# Initial condition loss: 2.6854e-08
# Boundary condition loss: 1.2959e-07
# --------------------------------------------------
# Epoch 45000/150000
# Total loss: 3.4034e-06
# Physics loss: 3.1263e-07
# Initial condition loss: 1.2392e-07
# Boundary condition loss: 1.5315e-07
# --------------------------------------------------
# Epoch 46500/150000
# Total loss: 2.2753e-06
# Physics loss: 2.0984e-07
# Initial condition loss: 4.9843e-08
# Boundary condition loss: 1.2708e-07
# --------------------------------------------------
# Epoch 48000/150000
# Total loss: 1.7691e-06
# Physics loss: 1.6196e-07
# Initial condition loss: 2.5505e-08
# Boundary condition loss: 1.2397e-07
# --------------------------------------------------
# Epoch 49500/150000
# Total loss: 1.5663e-06
# Physics loss: 1.4454e-07
# Initial condition loss: 1.4798e-08
# Boundary condition loss: 1.0610e-07
# --------------------------------------------------
# Epoch 51000/150000
# Total loss: 1.8994e-06
# Physics loss: 1.7126e-07
# Initial condition loss: 7.9246e-08
# Boundary condition loss: 1.0750e-07
# --------------------------------------------------
# Epoch 52500/150000
# Total loss: 1.4650e-06
# Physics loss: 1.3386e-07
# Initial condition loss: 2.0393e-08
# Boundary condition loss: 1.0595e-07
# --------------------------------------------------
# Epoch 54000/150000
# Total loss: 9.0016e-07
# Physics loss: 7.9507e-08
# Initial condition loss: 2.5611e-08
# Boundary condition loss: 7.9483e-08
# --------------------------------------------------
# Epoch 55500/150000
# Total loss: 9.5856e-07
# Physics loss: 8.5962e-08
# Initial condition loss: 2.5697e-08
# Boundary condition loss: 7.3244e-08
# --------------------------------------------------
# Epoch 57000/150000
# Total loss: 8.0521e-07
# Physics loss: 6.9981e-08
# Initial condition loss: 2.3967e-08
# Boundary condition loss: 8.1436e-08
# --------------------------------------------------
# Epoch 58500/150000
# Total loss: 8.3708e-07
# Physics loss: 7.2261e-08
# Initial condition loss: 3.4931e-08
# Boundary condition loss: 7.9542e-08
# --------------------------------------------------
# Epoch 60000/150000
# Total loss: 7.2921e-07
# Physics loss: 6.5896e-08
# Initial condition loss: 7.2177e-09
# Boundary condition loss: 6.3029e-08
# --------------------------------------------------
# Epoch 61500/150000
# Total loss: 6.9880e-07
# Physics loss: 6.1966e-08
# Initial condition loss: 1.6960e-08
# Boundary condition loss: 6.2185e-08
# --------------------------------------------------
# Epoch 63000/150000
# Total loss: 4.2319e-07
# Physics loss: 3.5883e-08
# Initial condition loss: 8.4294e-09
# Boundary condition loss: 5.5936e-08
# --------------------------------------------------
# Epoch 64500/150000
# Total loss: 5.8642e-07
# Physics loss: 5.2948e-08
# Initial condition loss: 7.4754e-09
# Boundary condition loss: 4.9462e-08
# --------------------------------------------------
# Epoch 66000/150000
# Total loss: 3.0978e-07
# Physics loss: 2.6299e-08
# Initial condition loss: 3.2912e-09
# Boundary condition loss: 4.3494e-08
# --------------------------------------------------
# Epoch 67500/150000
# Total loss: 4.7357e-07
# Physics loss: 4.2230e-08
# Initial condition loss: 5.8381e-09
# Boundary condition loss: 4.5430e-08
# --------------------------------------------------
# Epoch 69000/150000
# Total loss: 4.2772e-07
# Physics loss: 3.7637e-08
# Initial condition loss: 4.2665e-09
# Boundary condition loss: 4.7079e-08
# --------------------------------------------------
# Epoch 70500/150000
# Total loss: 2.5601e-07
# Physics loss: 2.0577e-08
# Initial condition loss: 6.9766e-09
# Boundary condition loss: 4.3272e-08
# --------------------------------------------------
# Epoch 72000/150000
# Total loss: 2.4098e-07
# Physics loss: 2.0424e-08
# Initial condition loss: 3.2365e-09
# Boundary condition loss: 3.3505e-08
# --------------------------------------------------
# Epoch 73500/150000
# Total loss: 3.2188e-07
# Physics loss: 2.8205e-08
# Initial condition loss: 3.1666e-09
# Boundary condition loss: 3.6660e-08
# --------------------------------------------------
# Epoch 75000/150000
# Total loss: 2.4267e-07
# Physics loss: 2.0135e-08
# Initial condition loss: 5.6438e-09
# Boundary condition loss: 3.5668e-08
# --------------------------------------------------
# Epoch 76500/150000
# Total loss: 1.9567e-07
# Physics loss: 1.5902e-08
# Initial condition loss: 3.7093e-09
# Boundary condition loss: 3.2950e-08
# --------------------------------------------------
# Epoch 78000/150000
# Total loss: 2.1674e-07
# Physics loss: 1.8243e-08
# Initial condition loss: 2.7710e-09
# Boundary condition loss: 3.1537e-08
# --------------------------------------------------
# Epoch 79500/150000
# Total loss: 1.6841e-07
# Physics loss: 1.3291e-08
# Initial condition loss: 4.7867e-09
# Boundary condition loss: 3.0711e-08
# --------------------------------------------------
# Epoch 81000/150000
# Total loss: 1.9663e-07
# Physics loss: 1.6249e-08
# Initial condition loss: 3.0100e-09
# Boundary condition loss: 3.1130e-08
# --------------------------------------------------
# Epoch 82500/150000
# Total loss: 1.4560e-07
# Physics loss: 1.1704e-08
# Initial condition loss: 3.8864e-09
# Boundary condition loss: 2.4675e-08
# --------------------------------------------------
# Epoch 84000/150000
# Total loss: 1.2349e-07
# Physics loss: 9.4362e-09
# Initial condition loss: 2.9259e-09
# Boundary condition loss: 2.6202e-08
# --------------------------------------------------
# Epoch 85500/150000
# Total loss: 1.1555e-07
# Physics loss: 9.1724e-09
# Initial condition loss: 1.8521e-09
# Boundary condition loss: 2.1969e-08
# --------------------------------------------------
# Epoch 87000/150000
# Total loss: 1.1979e-07
# Physics loss: 9.3766e-09
# Initial condition loss: 1.9992e-09
# Boundary condition loss: 2.4028e-08
# --------------------------------------------------
# Epoch 88500/150000
# Total loss: 1.2994e-07
# Physics loss: 9.8929e-09
# Initial condition loss: 2.3182e-09
# Boundary condition loss: 2.8694e-08
# --------------------------------------------------
# Epoch 90000/150000
# Total loss: 1.1012e-07
# Physics loss: 8.4416e-09
# Initial condition loss: 1.2911e-09
# Boundary condition loss: 2.4412e-08
# --------------------------------------------------
# Epoch 91500/150000
# Total loss: 1.1243e-07
# Physics loss: 8.6817e-09
# Initial condition loss: 3.0051e-09
# Boundary condition loss: 2.2606e-08
# --------------------------------------------------
# Epoch 93000/150000
# Total loss: 1.0879e-07
# Physics loss: 8.3633e-09
# Initial condition loss: 1.4730e-09
# Boundary condition loss: 2.3688e-08
# --------------------------------------------------
# Epoch 94500/150000
# Total loss: 9.8562e-08
# Physics loss: 7.4844e-09
# Initial condition loss: 1.6752e-09
# Boundary condition loss: 2.2043e-08
# --------------------------------------------------
# Epoch 96000/150000
# Total loss: 9.5316e-08
# Physics loss: 7.1748e-09
# Initial condition loss: 2.3231e-09
# Boundary condition loss: 2.1245e-08
# --------------------------------------------------
# Epoch 97500/150000
# Total loss: 8.6207e-08
# Physics loss: 6.2770e-09
# Initial condition loss: 1.5631e-09
# Boundary condition loss: 2.1874e-08
# --------------------------------------------------
# Epoch 99000/150000
# Total loss: 8.6836e-08
# Physics loss: 6.1819e-09
# Initial condition loss: 1.4924e-09
# Boundary condition loss: 2.3524e-08
# --------------------------------------------------
# Epoch 100500/150000
# Total loss: 8.9660e-08
# Physics loss: 7.0210e-09
# Initial condition loss: 1.3127e-09
# Boundary condition loss: 1.8137e-08
# --------------------------------------------------
# Epoch 102000/150000
# Total loss: 8.0657e-08
# Physics loss: 6.2848e-09
# Initial condition loss: 1.5004e-09
# Boundary condition loss: 1.6309e-08
# --------------------------------------------------
# Epoch 103500/150000
# Total loss: 7.8669e-08
# Physics loss: 5.6726e-09
# Initial condition loss: 1.2580e-09
# Boundary condition loss: 2.0685e-08
# --------------------------------------------------
# Epoch 105000/150000
# Total loss: 8.2252e-08
# Physics loss: 6.4344e-09
# Initial condition loss: 1.6321e-09
# Boundary condition loss: 1.6276e-08
# --------------------------------------------------
# Epoch 106500/150000
# Total loss: 7.8071e-08
# Physics loss: 5.8593e-09
# Initial condition loss: 1.5491e-09
# Boundary condition loss: 1.7929e-08
# --------------------------------------------------
# Epoch 108000/150000
# Total loss: 7.4150e-08
# Physics loss: 5.5218e-09
# Initial condition loss: 1.6379e-09
# Boundary condition loss: 1.7293e-08
# --------------------------------------------------
# Epoch 109500/150000
# Total loss: 6.7591e-08
# Physics loss: 5.0979e-09
# Initial condition loss: 1.4985e-09
# Boundary condition loss: 1.5113e-08
# --------------------------------------------------
# Epoch 111000/150000
# Total loss: 7.0009e-08
# Physics loss: 5.4764e-09
# Initial condition loss: 1.4083e-09
# Boundary condition loss: 1.3837e-08
# --------------------------------------------------
# Epoch 112500/150000
# Total loss: 6.8176e-08
# Physics loss: 5.3326e-09
# Initial condition loss: 1.2057e-09
# Boundary condition loss: 1.3644e-08
# --------------------------------------------------
# Epoch 114000/150000
# Total loss: 6.9682e-08
# Physics loss: 5.3769e-09
# Initial condition loss: 1.7362e-09
# Boundary condition loss: 1.4176e-08
# --------------------------------------------------
# Epoch 115500/150000
# Total loss: 6.9195e-08
# Physics loss: 5.2295e-09
# Initial condition loss: 1.6014e-09
# Boundary condition loss: 1.5298e-08
# --------------------------------------------------
# Epoch 117000/150000
# Total loss: 6.5948e-08
# Physics loss: 4.9608e-09
# Initial condition loss: 1.6431e-09
# Boundary condition loss: 1.4697e-08
# --------------------------------------------------
# Epoch 118500/150000
# Total loss: 6.5616e-08
# Physics loss: 4.9447e-09
# Initial condition loss: 1.8383e-09
# Boundary condition loss: 1.4331e-08
# --------------------------------------------------
# Epoch 120000/150000
# Total loss: 6.4056e-08
# Physics loss: 4.7404e-09
# Initial condition loss: 1.2943e-09
# Boundary condition loss: 1.5358e-08
# --------------------------------------------------
# Epoch 121500/150000
# Total loss: 6.4421e-08
# Physics loss: 5.0347e-09
# Initial condition loss: 1.3658e-09
# Boundary condition loss: 1.2708e-08
# --------------------------------------------------
# Epoch 123000/150000
# Total loss: 6.1143e-08
# Physics loss: 4.5587e-09
# Initial condition loss: 1.0768e-09
# Boundary condition loss: 1.4480e-08
# --------------------------------------------------
# Epoch 124500/150000
# Total loss: 6.3406e-08
# Physics loss: 4.6577e-09
# Initial condition loss: 1.3595e-09
# Boundary condition loss: 1.5470e-08
# --------------------------------------------------
# Epoch 126000/150000
# Total loss: 6.1854e-08
# Physics loss: 4.6886e-09
# Initial condition loss: 8.4424e-10
# Boundary condition loss: 1.4124e-08
# --------------------------------------------------
# Epoch 127500/150000
# Total loss: 5.7998e-08
# Physics loss: 4.6503e-09
# Initial condition loss: 1.2330e-09
# Boundary condition loss: 1.0262e-08
# --------------------------------------------------
# Epoch 129000/150000
# Total loss: 5.7051e-08
# Physics loss: 4.3817e-09
# Initial condition loss: 1.8536e-09
# Boundary condition loss: 1.1380e-08
# --------------------------------------------------
# Epoch 130500/150000
# Total loss: 5.6702e-08
# Physics loss: 4.3432e-09
# Initial condition loss: 1.1359e-09
# Boundary condition loss: 1.2134e-08
# --------------------------------------------------
# Epoch 132000/150000
# Total loss: 6.2137e-08
# Physics loss: 4.7430e-09
# Initial condition loss: 1.1820e-09
# Boundary condition loss: 1.3525e-08
# --------------------------------------------------
# Epoch 133500/150000
# Total loss: 5.9948e-08
# Physics loss: 4.5858e-09
# Initial condition loss: 1.5018e-09
# Boundary condition loss: 1.2588e-08
# --------------------------------------------------
# Epoch 135000/150000
# Total loss: 6.1266e-08
# Physics loss: 4.4158e-09
# Initial condition loss: 1.3119e-09
# Boundary condition loss: 1.5797e-08
# --------------------------------------------------
# Epoch 136500/150000
# Total loss: 6.0205e-08
# Physics loss: 4.4789e-09
# Initial condition loss: 9.9159e-10
# Boundary condition loss: 1.4425e-08
# --------------------------------------------------
# Epoch 138000/150000
# Total loss: 5.8036e-08
# Physics loss: 4.4963e-09
# Initial condition loss: 1.0338e-09
# Boundary condition loss: 1.2039e-08
# --------------------------------------------------
# Epoch 139500/150000
# Total loss: 5.3283e-08
# Physics loss: 4.0882e-09
# Initial condition loss: 1.6518e-09
# Boundary condition loss: 1.0750e-08
# --------------------------------------------------
# Epoch 141000/150000
# Total loss: 6.0353e-08
# Physics loss: 4.4553e-09
# Initial condition loss: 1.4568e-09
# Boundary condition loss: 1.4343e-08
# --------------------------------------------------
# Epoch 142500/150000
# Total loss: 5.2727e-08
# Physics loss: 4.0096e-09
# Initial condition loss: 1.1877e-09
# Boundary condition loss: 1.1443e-08
# --------------------------------------------------
# Epoch 144000/150000
# Total loss: 5.7064e-08
# Physics loss: 4.4130e-09
# Initial condition loss: 1.2702e-09
# Boundary condition loss: 1.1664e-08
# --------------------------------------------------
# Epoch 145500/150000
# Total loss: 5.9252e-08
# Physics loss: 4.4907e-09
# Initial condition loss: 1.2896e-09
# Boundary condition loss: 1.3055e-08
# --------------------------------------------------
# Epoch 147000/150000
# Total loss: 5.8393e-08
# Physics loss: 4.3353e-09
# Initial condition loss: 1.2237e-09
# Boundary condition loss: 1.3817e-08
# --------------------------------------------------
# Epoch 148500/150000
# Total loss: 5.7367e-08
# Physics loss: 4.1190e-09
# Initial condition loss: 1.1835e-09
# Boundary condition loss: 1.4994e-08
# --------------------------------------------------
# Epoch 150000/150000
# Total loss: 5.1611e-08
# Physics loss: 3.9598e-09
# Initial condition loss: 9.7755e-10
# Boundary condition loss: 1.1036e-08
# --------------------------------------------------

# %%
total_loss_history = [record['total_loss'] for record in history]
physics_loss_history = [record['physics_loss'] for record in history]
initial_condition_loss_history = [record['initial_condition_loss'] for record in history]
boundary_condition_loss_history = [record['boundary_condition_loss'] for record in history]

epochs_range = range(1, epochs + 1)

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 10))

# Total Loss
axs[0, 0].plot(epochs_range, total_loss_history, color='blue')
axs[0, 0].set_title('Total Loss')
axs[0, 0].set_xlabel('Epochs')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].grid(True)
axs[0, 0].set_yscale("log")

# Physics Loss
axs[0, 1].plot(epochs_range, physics_loss_history, color='orange')
axs[0, 1].set_title('Physics Loss')
axs[0, 1].set_xlabel('Epochs')
axs[0, 1].set_ylabel('Loss')
axs[0, 1].grid(True)
axs[0, 1].set_yscale("log")

# Initial Condition Loss
axs[1, 0].plot(epochs_range, initial_condition_loss_history, color='green')
axs[1, 0].set_title('Initial Condition Loss')
axs[1, 0].set_xlabel('Epochs')
axs[1, 0].set_ylabel('Loss')
axs[1, 0].grid(True)
axs[1, 0].set_yscale("log")

# Boundary Condition Loss
axs[1, 1].plot(epochs_range, boundary_condition_loss_history, color='red')
axs[1, 1].set_title('Boundary Condition Loss')
axs[1, 1].set_xlabel('Epochs')
axs[1, 1].set_ylabel('Loss')
axs[1, 1].grid(True)
axs[1, 1].set_yscale("log")

plt.tight_layout()
plt.show()

# %%
Nx = 628
Nt = 628

x_values = np.linspace(x_min, x_max, Nx)
t_values = np.linspace(t_min, t_max, Nt)

# %% [markdown]
# #### For the analytical solution, we need to introduce constants which were taken as 1 for our previous models

# %%
E0 = 0.5 * omega * hbar
A = (m * omega / (np.pi * hbar)) ** 0.25
alpha = (m * omega) / (2.0 * hbar)

# %%
psi_real_analytical = np.zeros((Nx, Nt), dtype=np.float64)
psi_img_analytical = np.zeros((Nx, Nt), dtype=np.float64)

for i, x in enumerate(x_values):
  psi0_x = A * np.exp(-alpha * x ** 2)

  for j, t in enumerate(t_values):
    phase = -E0 * t / hbar
    exp_phase = np.exp(1j * phase)

    psi_x_t = psi0_x * exp_phase

    psi_real_analytical[i, j] = np.real(psi_x_t)
    psi_img_analytical[i, j] = np.imag(psi_x_t)

# %%
plt.figure(figsize=(8, 6))
psi_sq_analytical = psi_real_analytical ** 2 + psi_img_analytical ** 2

plt.pcolormesh(x_values, t_values, psi_sq_analytical.transpose(), shading="auto")
plt.colorbar(label='|psi(x,t)|^2')
plt.xlabel('x')
plt.ylabel('t')
plt.title('Analytical |psi|^2')
plt.show()

# %%
x_values_torch = torch.from_numpy(x_values).float().to(device)
t_values_torch = torch.from_numpy(t_values).float().to(device)

x_grid, t_grid = torch.meshgrid(x_values_torch, t_values_torch, indexing="ij")

x_flat = torch.reshape(x_grid, [-1])
t_flat = torch.reshape(t_grid, [-1])

psi_real_pinn, psi_img_pinn = model((x_flat, t_flat))

psi_real_pinn = torch.reshape(psi_real_pinn, (Nx, Nt))
psi_img_pinn = torch.reshape(psi_img_pinn, (Nx, Nt))

psi_real_pinn = psi_real_pinn.detach().cpu().numpy()
psi_img_pinn = psi_img_pinn.detach().cpu().numpy()

# %%
plt.figure(figsize=(8, 6))
psi_sq = psi_real_pinn ** 2 + psi_img_pinn ** 2

plt.pcolormesh(x_values, t_values, psi_sq.transpose(), shading="auto")
plt.colorbar(label='|psi(x,t)|^2')
plt.xlabel('x')
plt.ylabel('t')
plt.title('PINN |psi|^2')
plt.show()

# %%
plt.figure(figsize=(8, 6))
psi_sq_diff = np.abs(psi_sq - psi_sq_analytical)

plt.pcolormesh(x_values, t_values, psi_sq_diff.transpose(), shading="auto")
plt.colorbar(label='|psi(x,t)|^2')
plt.xlabel('x')
plt.ylabel('t')
plt.title('PINN |psi|^2')
plt.show()

# %%
psi_analytical_mag = psi_real_analytical ** 2 + psi_img_analytical ** 2
psi_pinn_mag = psi_real_pinn ** 2 + psi_img_pinn ** 2

mse = (np.square(psi_analytical_mag - psi_pinn_mag)).mean()

print(f"Mean Squared Error: {mse:.3e}")
# Out:
# Mean Squared Error: 9.306e-11

# %%
from scipy.integrate import simpson

norms = []

for i in range(628):
	psi_sq = psi_real_pinn[:, i] ** 2 + psi_img_pinn[:, i] ** 2
	normalization = simpson(psi_sq, x=x_values)
	norms.append(normalization)

plt.figure(figsize=(8,5))
plt.plot(t_values, norms, '-', label='Normalization')
plt.axhline(1.0, color='red', linestyle='--', label='Expected = 1')
plt.xlabel('Time (ps)')
plt.ylabel('Normalization')
plt.title('Wavefunction Normalization Over Time')
plt.legend()
plt.grid(True)
plt.show()
